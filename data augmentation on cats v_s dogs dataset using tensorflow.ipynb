# %%
# In this exercise you will train a CNN on the FULL Cats-v-dogs dataset
# This will require you doing a lot of data preprocessing because
# the dataset isn't split into training and validation for you
# This code block has all the required inputs
import os
import zipfile
import random
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile

# %%
# This code block downloads the full Cats-v-Dogs dataset and stores it as 
# cats-and-dogs.zip. It then unzips it to /tmp
# which will create a tmp/PetImages directory containing subdirectories
# called 'Cat' and 'Dog' (that's how the original researchers structured it)
# If the URL doesn't work, 
# .   visit https://www.microsoft.com/en-us/download/confirmation.aspx?id=54765
# And right click on the 'Download Manually' link to get a new URL

# !wget --no-check-certificate \
    "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip" \
    -O "/tmp/cats-and-dogs.zip"

local_zip = '/tmp/cats-and-dogs.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()
# Out:
# --2020-05-16 19:30:43--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 2.17.220.144, 2a02:26f0:64:5a8::e59, 2a02:26f0:64:585::e59
# Connecting to download.microsoft.com (download.microsoft.com)|2.17.220.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘/tmp/cats-and-dogs.zip’
#
# /tmp/cats-and-dogs. 100%[===================>] 786.68M  22.8MB/s    in 26s
#
# 2020-05-16 19:31:09 (30.1 MB/s) - ‘/tmp/cats-and-dogs.zip’ saved [824894548/824894548]

# %%
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/')))

# Expected Output:
# 12501
# 12501
# Out:
# 12501
# 12501

# %%
# Use os.mkdir to create your directories
# You will need a directory for cats-v-dogs, and subdirectories for training
# and testing. These in turn will need subdirectories for 'cats' and 'dogs'
try:
    os.mkdir("/tmp/cats-v-dogs/")
    os.mkdir("/tmp/cats-v-dogs/testing/")
    os.mkdir("/tmp/cats-v-dogs/training")
    os.mkdir("/tmp/cats-v-dogs/training/cats/")
    os.mkdir("/tmp/cats-v-dogs/training/dogs/")
    os.mkdir("/tmp/cats-v-dogs/testing/cats/")
    os.mkdir("/tmp/cats-v-dogs/testing/dogs/")
except OSError:
    pass

# %%
# Write a python function called split_data which takes
# a SOURCE directory containing the files
# a TRAINING directory that a portion of the files will be copied to
# a TESTING directory that a portion of the files will be copie to
# a SPLIT SIZE to determine the portion
# The files should also be randomized, so that the training set is a random
# X% of the files, and the test set is the remaining files
# SO, for example, if SOURCE is PetImages/Cat, and SPLIT SIZE is .9
# Then 90% of the images in PetImages/Cat will be copied to the TRAINING dir
# and 10% of the images will be copied to the TESTING dir
# Also -- All images should be checked, and if they have a zero file length,
# they will not be copied over
#
# os.listdir(DIRECTORY) gives you a listing of the contents of that directory
# os.path.getsize(PATH) gives you the size of the file
# copyfile(source, destination) copies a file from source to destination
# random.sample(list, len(list)) shuffles a list
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
# YOUR CODE STARTS HERE
    temp = os.listdir(SOURCE)
    files = []
    for f in temp:
        if os.path.getsize(SOURCE+f)==0:
            print(f"{f} is zero length, so ignoring")
        else:
            files.append(f)
    training_size = int(len(files) * split_size)
    test_size = int(len(files) * (1-split_size))

    files = random.sample(files, len(files))
    train = files[:training_size]
    test = files[-test_size-1:]
    for f in train:
        copyfile(SOURCE+f, TRAINING+f)
    for f in test:
        copyfile(SOURCE+f, TESTING+f)
# YOUR CODE ENDS HERE


CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"

split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)

# Expected output
# 666.jpg is zero length, so ignoring
# 11702.jpg is zero length, so ignoring
# Out:
# 666.jpg is zero length, so ignoring
# 11702.jpg is zero length, so ignoring

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))

# Expected output:
# 11250
# 11250
# 1250
# 1250
# Out:
# 11250
# 11250
# 1250
# 1250

# %%
# DEFINE A KERAS MODEL TO CLASSIFY CATS V DOGS
# USE AT LEAST 3 CONVOLUTION LAYERS
model = tf.keras.models.Sequential([
# YOUR CODE HERE
    tf.keras.layers.Conv2D(16,(3,3),input_shape=(150,150,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
TRAINING_DIR = "/tmp/cats-v-dogs/training"
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range = 40,
                                   width_shift_range=0.3,
                                   height_shift_range = 0.3,
                                   shear_range = 0.2,
                                   zoom_range= 0.2,
                                   fill_mode=  'nearest')
train_generator = train_datagen.flow_from_directory(TRAINING_DIR,target_size=(150,150),
                                                    class_mode = 'binary')

VALIDATION_DIR = "/tmp/cats-v-dogs/testing"
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,target_size=(150,150),
                                                    class_mode = 'binary')
# Expected Output:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# Out:
# Found 22498 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %%
history = model.fit(train_generator,
                              epochs=100,
                              verbose=1,
                              validation_data=validation_generator,
                    validation_steps = 10,
                    steps_per_epoch = 30)

# The expectation here is that the model will train, and that accuracy will be > 95% on both training and validation
# i.e. acc:A1 and val_acc:A2 will be visible, and both A1 and A2 will be > .9
# Out:
# Epoch 1/100
# 30/30 [==============================] - 8s 260ms/step - loss: 1.0199 - accuracy: 0.4990 - val_loss: 0.6909 - val_accuracy: 0.5437
# Epoch 2/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6914 - accuracy: 0.5375 - val_loss: 0.6960 - val_accuracy: 0.5406
# Epoch 3/100
# 30/30 [==============================] - 8s 260ms/step - loss: 0.7036 - accuracy: 0.5521 - val_loss: 0.6796 - val_accuracy: 0.6031
# Epoch 4/100
# 30/30 [==============================] - 8s 257ms/step - loss: 0.7229 - accuracy: 0.5344 - val_loss: 0.6708 - val_accuracy: 0.6000
# Epoch 5/100
# 30/30 [==============================] - ETA: 0s - loss: 0.6897 - accuracy: 0.5667
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:770: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag)
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 30/30 [==============================] - 8s 257ms/step - loss: 0.6897 - accuracy: 0.5667 - val_loss: 0.6867 - val_accuracy: 0.5562
# Epoch 6/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6894 - accuracy: 0.5562 - val_loss: 0.7324 - val_accuracy: 0.4781
# Epoch 7/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6986 - accuracy: 0.5750 - val_loss: 0.6845 - val_accuracy: 0.5281
# Epoch 8/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6608 - accuracy: 0.6031 - val_loss: 0.6815 - val_accuracy: 0.5685
# Epoch 9/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6644 - accuracy: 0.6083 - val_loss: 0.6998 - val_accuracy: 0.5688
# Epoch 10/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6808 - accuracy: 0.5865 - val_loss: 0.6529 - val_accuracy: 0.6031
# Epoch 11/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6654 - accuracy: 0.5885 - val_loss: 0.9796 - val_accuracy: 0.4875
# Epoch 12/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6669 - accuracy: 0.6198 - val_loss: 0.7067 - val_accuracy: 0.5344
# Epoch 13/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6426 - accuracy: 0.6187 - val_loss: 0.6193 - val_accuracy: 0.6469
# Epoch 14/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6744 - accuracy: 0.6031 - val_loss: 0.6503 - val_accuracy: 0.5813
# Epoch 15/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6588 - accuracy: 0.6010 - val_loss: 0.6303 - val_accuracy: 0.6918
# Epoch 16/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6529 - accuracy: 0.6281 - val_loss: 0.6229 - val_accuracy: 0.6094
# Epoch 17/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.6725 - accuracy: 0.6062 - val_loss: 0.6186 - val_accuracy: 0.6594
# Epoch 18/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6460 - accuracy: 0.6187 - val_loss: 0.6245 - val_accuracy: 0.6375
# Epoch 19/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6758 - accuracy: 0.6240 - val_loss: 0.6115 - val_accuracy: 0.6375
# Epoch 20/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6325 - accuracy: 0.6542 - val_loss: 0.6260 - val_accuracy: 0.6656
# Epoch 21/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6425 - accuracy: 0.6292 - val_loss: 0.5841 - val_accuracy: 0.7094
# Epoch 22/100
# 30/30 [==============================] - 8s 250ms/step - loss: 0.6235 - accuracy: 0.6500 - val_loss: 0.6032 - val_accuracy: 0.6370
# Epoch 23/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6190 - accuracy: 0.6510 - val_loss: 0.6663 - val_accuracy: 0.6344
# Epoch 24/100
# 30/30 [==============================] - 7s 247ms/step - loss: 0.6467 - accuracy: 0.6495 - val_loss: 0.6017 - val_accuracy: 0.6906
# Epoch 25/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6318 - accuracy: 0.6313 - val_loss: 0.5801 - val_accuracy: 0.6781
# Epoch 26/100
# 30/30 [==============================] - 8s 258ms/step - loss: 0.6247 - accuracy: 0.6490 - val_loss: 0.5843 - val_accuracy: 0.6844
# Epoch 27/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6266 - accuracy: 0.6562 - val_loss: 0.5582 - val_accuracy: 0.6938
# Epoch 28/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6244 - accuracy: 0.6510 - val_loss: 0.5899 - val_accuracy: 0.6906
# Epoch 29/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.6507 - accuracy: 0.6531 - val_loss: 0.6150 - val_accuracy: 0.6438
# Epoch 30/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6162 - accuracy: 0.6667 - val_loss: 0.5835 - val_accuracy: 0.6969
# Epoch 31/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6285 - accuracy: 0.6573 - val_loss: 0.5529 - val_accuracy: 0.7219
# Epoch 32/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6198 - accuracy: 0.6667 - val_loss: 0.5263 - val_accuracy: 0.7563
# Epoch 33/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6270 - accuracy: 0.6687 - val_loss: 0.5421 - val_accuracy: 0.7188
# Epoch 34/100
# 30/30 [==============================] - 8s 258ms/step - loss: 0.6129 - accuracy: 0.6719 - val_loss: 0.5513 - val_accuracy: 0.7094
# Epoch 35/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.6270 - accuracy: 0.6490 - val_loss: 0.5543 - val_accuracy: 0.7344
# Epoch 36/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6149 - accuracy: 0.6865 - val_loss: 0.5924 - val_accuracy: 0.6781
# Epoch 37/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.6234 - accuracy: 0.6625 - val_loss: 0.5843 - val_accuracy: 0.6750
# Epoch 38/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6166 - accuracy: 0.6740 - val_loss: 0.5469 - val_accuracy: 0.6875
# Epoch 39/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6011 - accuracy: 0.6802 - val_loss: 0.5750 - val_accuracy: 0.6906
# Epoch 40/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.6451 - accuracy: 0.6354 - val_loss: 0.6069 - val_accuracy: 0.6500
# Epoch 41/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5980 - accuracy: 0.6656 - val_loss: 0.5459 - val_accuracy: 0.7219
# Epoch 42/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6229 - accuracy: 0.6677 - val_loss: 0.5771 - val_accuracy: 0.6875
# Epoch 43/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6176 - accuracy: 0.6719 - val_loss: 0.5653 - val_accuracy: 0.6844
# Epoch 44/100
# 30/30 [==============================] - 7s 249ms/step - loss: 0.6108 - accuracy: 0.6698 - val_loss: 0.5671 - val_accuracy: 0.7089
# Epoch 45/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6170 - accuracy: 0.6844 - val_loss: 0.5064 - val_accuracy: 0.7500
# Epoch 46/100
# 30/30 [==============================] - 8s 257ms/step - loss: 0.6523 - accuracy: 0.6656 - val_loss: 0.5656 - val_accuracy: 0.6938
# Epoch 47/100
# 30/30 [==============================] - 7s 250ms/step - loss: 0.6069 - accuracy: 0.6828 - val_loss: 0.6192 - val_accuracy: 0.6750
# Epoch 48/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5935 - accuracy: 0.6594 - val_loss: 0.5622 - val_accuracy: 0.7094
# Epoch 49/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.6165 - accuracy: 0.6823 - val_loss: 0.5536 - val_accuracy: 0.7156
# Epoch 50/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.6064 - accuracy: 0.6729 - val_loss: 0.5914 - val_accuracy: 0.7031
# Epoch 51/100
# 30/30 [==============================] - 7s 249ms/step - loss: 0.5906 - accuracy: 0.6729 - val_loss: 0.5550 - val_accuracy: 0.7123
# Epoch 52/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.5910 - accuracy: 0.6833 - val_loss: 0.6505 - val_accuracy: 0.6094
# Epoch 53/100
# 30/30 [==============================] - 8s 250ms/step - loss: 0.5826 - accuracy: 0.6844 - val_loss: 0.5775 - val_accuracy: 0.7281
# Epoch 54/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.5839 - accuracy: 0.6958 - val_loss: 0.5504 - val_accuracy: 0.7156
# Epoch 55/100
# 30/30 [==============================] - 8s 267ms/step - loss: 0.5891 - accuracy: 0.6917 - val_loss: 0.5553 - val_accuracy: 0.6969
# Epoch 56/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.6111 - accuracy: 0.6875 - val_loss: 0.5459 - val_accuracy: 0.7563
# Epoch 57/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.5753 - accuracy: 0.6927 - val_loss: 0.4965 - val_accuracy: 0.7781
# Epoch 58/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.5627 - accuracy: 0.7281 - val_loss: 0.5029 - val_accuracy: 0.7363
# Epoch 59/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6023 - accuracy: 0.7031 - val_loss: 0.5532 - val_accuracy: 0.7031
# Epoch 60/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6055 - accuracy: 0.6656 - val_loss: 0.5993 - val_accuracy: 0.6531
# Epoch 61/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5966 - accuracy: 0.6802 - val_loss: 0.5125 - val_accuracy: 0.7625
# Epoch 62/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5903 - accuracy: 0.6854 - val_loss: 0.5493 - val_accuracy: 0.7281
# Epoch 63/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.5809 - accuracy: 0.6896 - val_loss: 0.5183 - val_accuracy: 0.7125
# Epoch 64/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5807 - accuracy: 0.7083 - val_loss: 0.5146 - val_accuracy: 0.7250
# Epoch 65/100
# 30/30 [==============================] - 8s 250ms/step - loss: 0.6092 - accuracy: 0.6812 - val_loss: 0.6491 - val_accuracy: 0.6712
# Epoch 66/100
# 30/30 [==============================] - 8s 257ms/step - loss: 0.6028 - accuracy: 0.6802 - val_loss: 0.4793 - val_accuracy: 0.7844
# Epoch 67/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.5771 - accuracy: 0.6979 - val_loss: 0.5045 - val_accuracy: 0.7344
# Epoch 68/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5742 - accuracy: 0.7083 - val_loss: 0.5175 - val_accuracy: 0.7719
# Epoch 69/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.6015 - accuracy: 0.6875 - val_loss: 0.5149 - val_accuracy: 0.7437
# Epoch 70/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5940 - accuracy: 0.6896 - val_loss: 0.5946 - val_accuracy: 0.7219
# Epoch 71/100
# 30/30 [==============================] - 7s 247ms/step - loss: 0.5939 - accuracy: 0.6925 - val_loss: 0.5299 - val_accuracy: 0.7063
# Epoch 72/100
# 30/30 [==============================] - 8s 251ms/step - loss: 0.6047 - accuracy: 0.6740 - val_loss: 0.5017 - val_accuracy: 0.7500
# Epoch 73/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5947 - accuracy: 0.6875 - val_loss: 0.5292 - val_accuracy: 0.7625
# Epoch 74/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5863 - accuracy: 0.6792 - val_loss: 0.5499 - val_accuracy: 0.7219
# Epoch 75/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.6101 - accuracy: 0.6698 - val_loss: 0.6567 - val_accuracy: 0.6281
# Epoch 76/100
# 30/30 [==============================] - 8s 260ms/step - loss: 0.5603 - accuracy: 0.6938 - val_loss: 0.5388 - val_accuracy: 0.6969
# Epoch 77/100
# 30/30 [==============================] - 8s 257ms/step - loss: 0.6097 - accuracy: 0.6802 - val_loss: 0.5067 - val_accuracy: 0.7250
# Epoch 78/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.5787 - accuracy: 0.7042 - val_loss: 0.5147 - val_accuracy: 0.7750
# Epoch 79/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5753 - accuracy: 0.7167 - val_loss: 0.4414 - val_accuracy: 0.8125
# Epoch 80/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5576 - accuracy: 0.7229 - val_loss: 0.5271 - val_accuracy: 0.7344
# Epoch 81/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.5734 - accuracy: 0.7010 - val_loss: 0.4762 - val_accuracy: 0.7688
# Epoch 82/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.6040 - accuracy: 0.6844 - val_loss: 0.5612 - val_accuracy: 0.7312
# Epoch 83/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5706 - accuracy: 0.7010 - val_loss: 0.5033 - val_accuracy: 0.7531
# Epoch 84/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5463 - accuracy: 0.7219 - val_loss: 0.6362 - val_accuracy: 0.7188
# Epoch 85/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5938 - accuracy: 0.6938 - val_loss: 0.5088 - val_accuracy: 0.7406
# Epoch 86/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5801 - accuracy: 0.7073 - val_loss: 0.5563 - val_accuracy: 0.7250
# Epoch 87/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.5856 - accuracy: 0.6906 - val_loss: 0.5254 - val_accuracy: 0.7500
# Epoch 88/100
# 30/30 [==============================] - 8s 257ms/step - loss: 0.5695 - accuracy: 0.7146 - val_loss: 0.5276 - val_accuracy: 0.7250
# Epoch 89/100
# 30/30 [==============================] - 8s 258ms/step - loss: 0.6020 - accuracy: 0.6917 - val_loss: 0.4998 - val_accuracy: 0.7844
# Epoch 90/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5550 - accuracy: 0.7052 - val_loss: 0.5239 - val_accuracy: 0.7281
# Epoch 91/100
# 30/30 [==============================] - 8s 252ms/step - loss: 0.5694 - accuracy: 0.7052 - val_loss: 0.5020 - val_accuracy: 0.7281
# Epoch 92/100
# 30/30 [==============================] - 8s 256ms/step - loss: 0.5774 - accuracy: 0.6875 - val_loss: 0.6766 - val_accuracy: 0.6875
# Epoch 93/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5637 - accuracy: 0.7115 - val_loss: 0.7858 - val_accuracy: 0.6625
# Epoch 94/100
# 30/30 [==============================] - 7s 245ms/step - loss: 0.5978 - accuracy: 0.6785 - val_loss: 0.5833 - val_accuracy: 0.6712
# Epoch 95/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5850 - accuracy: 0.7031 - val_loss: 0.5085 - val_accuracy: 0.7281
# Epoch 96/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5733 - accuracy: 0.6760 - val_loss: 0.4917 - val_accuracy: 0.7500
# Epoch 97/100
# 30/30 [==============================] - 8s 259ms/step - loss: 0.5804 - accuracy: 0.7000 - val_loss: 0.4957 - val_accuracy: 0.7656
# Epoch 98/100
# 30/30 [==============================] - 8s 253ms/step - loss: 0.5798 - accuracy: 0.6969 - val_loss: 0.4868 - val_accuracy: 0.7594
# Epoch 99/100
# 30/30 [==============================] - 8s 255ms/step - loss: 0.5707 - accuracy: 0.7010 - val_loss: 0.5536 - val_accuracy: 0.7437
# Epoch 100/100
# 30/30 [==============================] - 8s 254ms/step - loss: 0.5482 - accuracy: 0.7208 - val_loss: 0.5062 - val_accuracy: 0.7719

# %%
# PLOT LOSS AND ACCURACY
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')

# Desired output. Charts with training and validation metrics. No crash :)
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
# Here's a codeblock just for fun. You should be able to upload an image here 
# and have it classified without crashing

import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = '/content/' + fn
  img = image.load_img(path, target_size=(150,150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  print(classes[0])
  if classes[0]>0.5:
    print(fn + " is a dog")
  else:
    print(fn + " is a cat")
# Out:
# Using TensorFlow backend.
#      <input type="file" id="files-47f4923a-ca87-4f12-9776-2db63cc44eb3" name="files[]" multiple disabled />
#      <output id="result-47f4923a-ca87-4f12-9776-2db63cc44eb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.webp to dog.webp
# [0.9999763]
# dog.webp is a dog
